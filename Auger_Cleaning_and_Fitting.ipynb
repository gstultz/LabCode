# %%
from LittleMachineLib import Auger
# %matplotlib inline

# %%
filename = 'nov01_17.a02'

# %%
a = Auger(filename)
a.plot_data()
# Out:
# Data has not been loaded yet, calling load_data()...
# Auger file nov01_17.a02 has been preprocessed, loading the data...
# Data loaded successfully!

# %%
a.fit_Au_coverage()
# Out:
# Au coverage is 0.562 ML
