# %%
# %matplotlib notebook
from LittleMachine_TDS_Lib import CIRD

# %%
cird = CIRD("dec20_17.c01")

# %%
cird.load_data(show_plot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cird.data.head()
# Out:
#    counts    temp  time
# 0  3390.0  71.900   0.0
# 1  3420.0  71.881   0.2
# 2  3505.0  71.959   0.4
# 3  3520.0  71.746   0.6
# 4  3470.0  71.926   0.8

# %%
cird.level_background()
# Out:
# Estimated beam stop time: 193
# Please enter the sensitivity factor:0.7483

# %%
jcird.data.head()
# Out:
#    counts    temp  time  counts_leveled_background
# 0  3390.0  71.900   0.0                 304.411005
# 1  3420.0  71.881   0.2                 363.355675
# 2  3505.0  71.959   0.4                 530.742146
# 3  3520.0  71.746   0.6                 560.111779
# 4  3470.0  71.926   0.8                 461.322920

# %%
cird.peak_fit(area_high=False)
# Out:
# [  4.46189216e+02   3.06352654e+02  -2.55493178e-02  -9.17992993e-02
#    7.35010644e+01   7.31384686e+01   1.46729729e+02]
# 66.6

# %%
cird.create_plot(area_high=False)
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
cird.data.head()
# Out:
#    counts    temp  time  counts_leveled_background  exponential_fit
# 0  3390.0  71.900   0.0                 304.411005              0.0
# 1  3420.0  71.881   0.2                 363.355675              0.0
# 2  3505.0  71.959   0.4                 530.742146              0.0
# 3  3520.0  71.746   0.6                 560.111779              0.0
# 4  3470.0  71.926   0.8                 461.322920              0.0

# %%
cird.write_file()
# Out:
# Do you want to save the data to pdec20_17.c01? (Y/N): y
# Success!
