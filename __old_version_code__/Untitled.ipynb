# %%
from EELSLib import EELS

# %%
filename = "mar28_18.e02"

# %%
a = EELS(filename)

# %%
a.load_data(ymax=20, spike_removal=True, overwrite=True)
# Out:
# EELS mar28_18.e02 not preprocessed, now preprocessing...
# 17 spikes found at the following locations:
# 347.00
# 436.00
# 437.00
# 438.00
# 439.00
# 440.00
# 441.00
# 442.00
# 449.00
# 450.00
# 451.00
# 452.00
# 453.00
# 454.00
# 455.00
# 478.00
# 481.00
# Data loaded successfully!

# %%
a.plot_data(cutoff=200)

# %%
a.fit_EELS(yHeight=100)
# Out:
# [[Model]]
#     (((Model(linear) + Model(voigt, prefix='elas_')) + Model(lorentzian, prefix='loss1_')) + Model(lorentzian, prefix='loss2_'))
# [[Fit Statistics]]
#     # function evals   = 961
#     # data points      = 511
#     # variables        = 11
#     chi-square         = 898012.144
#     reduced chi-square = 1796.024
#     Akaike info crit   = 3839.972
#     Bayesian info crit = 3886.572
# [[Variables]]
#     intercept:        -9.99893968 +/- 6.352827 (63.54%) (init= 0)
#     slope:            -5.5096e-14 +/- 2.25e+04 (40825809669354872832.00%) (init= 0)
#     elas_center:      -6.57724215 +/- 0.072604 (1.10%) (init= 0)
#     elas_amplitude:    8.8700e+05 +/- 2.41e+03 (0.27%) (init= 40)
#     elas_sigma:        18.4039708 +/- 0.057809 (0.31%) (init= 10)
#     elas_gamma:        18.4039708 +/- 0.057809 (0.31%)  == 'elas_sigma'
#     elas_fwhm:         66.2784043 +/- 0.208190 (0.31%)  == '3.6013100*elas_sigma'
# ...
