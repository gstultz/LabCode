# %%
from lib.auger import Auger
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2018-07-08 18:30:51.855277] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-07-08 18:30:51.856382] TRACE: Program: Folder located successfully: /Users/denny/Dropbox (MIT)/Little Machine Data
# [2018-07-08 18:30:51.863269] TRACE: Program: File /Users/denny/Dropbox (MIT)/Little Machine Data/Auger/2018/07_jul/jul05_18.a01 copied to /Users/denny/Dropbox (MIT)/littlemachine/2018/07_jul/jul05_18.a01
# [2018-07-08 18:30:53.755190] TRACE: Program: Folder created: /Users/denny/Dropbox (MIT)/Little Machine Data/EELS/2018/07_jul
# [2018-07-08 18:30:53.756122] TRACE: Program: File /Users/denny/Dropbox (MIT)/Little Machine Data/EELS/2018/07_jul/jul05_18.e01 copied to /Users/denny/Dropbox (MIT)/littlemachine/2018/07_jul/jul05_18.e01
# [2018-07-08 18:30:55.120710] TRACE: Program: File /Users/denny/Dropbox (MIT)/Little Machine Data/EELS/2018/07_jul/jul02_18.e02 copied to /Users/denny/Dropbox (MIT)/littlemachine/2018/07_jul/jul02_18.e02
# [2018-07-08 18:30:56.604159] TRACE: Program: File /Users/denny/Dropbox (MIT)/Little Machine Data/EELS/2018/07_jul/jul05_18.e02 copied to /Users/denny/Dropbox (MIT)/littlemachine/2018/07_jul/jul05_18.e02
# [2018-07-08 18:30:58.251172] TRACE: Program: Files transfer completed

# %%
filename = "jul05_18.a01"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger jul05_18.a01 not preprocessed, now preprocessing...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
