# %%
from lib.auger import Auger
from lib.file_transfer import file_transfer
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
file_transfer()
# Out:
# [2018-08-13 20:26:10.227495] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-08-13 20:26:10.229144] TRACE: Program: Folder located successfully: /home/jovyan/Dropbox (MIT)/Little Machine Data
# [2018-08-13 20:26:10.253055] TRACE: Program: File /home/jovyan/Dropbox (MIT)/Little Machine Data/EELS/2018/08_aug/aug10_18.e01 copied to /home/jovyan/Dropbox (MIT)/littlemachine/2018/08_aug/aug10_18.e01
# [2018-08-13 20:26:10.256199] TRACE: Program: File /home/jovyan/Dropbox (MIT)/Little Machine Data/EELS/2018/08_aug/aug10_18.e02 copied to /home/jovyan/Dropbox (MIT)/littlemachine/2018/08_aug/aug10_18.e02
# [2018-08-13 20:26:10.297673] TRACE: Program: File /home/jovyan/Dropbox (MIT)/Little Machine Data/Auger/2018/08_aug/aug10_18.a02 copied to /home/jovyan/Dropbox (MIT)/littlemachine/2018/08_aug/aug10_18.a02
# [2018-08-13 20:26:10.299406] TRACE: Program: File /home/jovyan/Dropbox (MIT)/Little Machine Data/Auger/2018/08_aug/aug10_18.a01 copied to /home/jovyan/Dropbox (MIT)/littlemachine/2018/08_aug/aug10_18.a01
# [2018-08-13 20:26:10.324070] TRACE: Program: Files transfer completed

# %%
filename = "aug10_18.a02"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger aug10_18.a02 not preprocessed, now preprocessing...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'A': array([0.442, 0.034]), 'B': array([0.441, 0.035])}"
