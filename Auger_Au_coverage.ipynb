# %%
from lib.auger import Auger
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2018-06-26 20:56:57.670108] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-06-26 20:56:57.671279] TRACE: Program: Folder located successfully: /home/yang/Dropbox (MIT)/Little Machine Data
# [2018-06-26 20:56:57.720407] TRACE: Program: Files transfer completed

# %%
filename = "feb01_18.a02"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger feb01_18.a02 not preprocessed, now preprocessing...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'A': array([0.271, 0.049]), 'B': array([0.273, 0.046])}"
