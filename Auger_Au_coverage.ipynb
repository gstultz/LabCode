# %%
# from AugerLib import Auger
from AugerLib_Thesis import Auger

# %%
filename = "may09_18.a01"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger may09_18.a01 not preprocessed, now preprocessing...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'B': array([ 0.253,  0.014]), 'A': array([ 0.247,  0.04 ])}"
