# %%
from lib.auger import Auger
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2018-07-16 14:43:42.088150] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-07-16 14:43:42.089464] TRACE: Program: Folder located successfully: /home/yang/Dropbox (MIT)/Little Machine Data
# [2018-07-16 14:43:42.144638] TRACE: Program: Files transfer completed

# %%
filename = "jul11_18.a02"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger jul11_18.a02 already preprocessed, loading data...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'A': array([0.436, 0.021])}"
