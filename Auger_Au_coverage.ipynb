# %%
# from AugerLib import Auger
from AugerLib_Thesis import Auger

# %%
filename = "may17_18.a01"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger may17_18.a01 already preprocessed, loading data...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'A': array([ 0.193,  0.043]), 'B': array([ 0.211,  0.014])}"
