# %%
# %matplotlib inline
from lib.eels import EELS
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2018-08-23 19:42:27.246422] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-08-23 19:42:27.248514] TRACE: Program: Folder located successfully: /home/jovyan/Dropbox (MIT)/Little Machine Data
# [2018-08-23 19:42:27.326737] TRACE: Program: Files transfer completed

# %%
filename = 'aug02_18.e02'
e = EELS(filename)

ymax = 100
spike_removal = True

e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS aug02_18.e02 already preprocessed, loading data...
# Data loaded successfully!

# %%
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
# Out:
# EELS aug02_18.e02 already preprocessed, loading data...
# Data loaded successfully!

# %%
e.plot_data(cutoff=300)
