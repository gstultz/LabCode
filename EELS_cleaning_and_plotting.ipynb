# %%
# %matplotlib inline
from lib.eels import EELS
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2018-08-19 02:06:13.006391] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2018-08-19 02:06:13.008394] TRACE: Program: Folder located successfully: C:\Users\Yang Dai\Dropbox (MIT)\Little Machine Data
# [2018-08-19 02:06:13.885491] TRACE: Program: Files transfer completed

# %%
filename = 'aug02_18.e20'
e = EELS(filename)

ymax = 100
spike_removal = True

e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS aug02_18.e20 not preprocessed, now preprocessing...
# 0 spikes found at the following locations:
# Data loaded successfully!

# %%
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
# Out:
# EELS aug02_18.e20 not preprocessed, now preprocessing...
# 0 spikes found at the following locations:
# Data loaded successfully!

# %%
e.plot_data(cutoff=300)
