# %%
# %matplotlib inline

from lib.eels import EELS
from lib.file_transfer import file_transfer

# %%
filename = 'jul11_18.e02'
e = EELS(filename)

ymax = 100
spike_removal = True

e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS jul11_18.e02 not preprocessed, now preprocessing...
# 6 spikes found at the following locations:
# 99.00
# 129.00
# 150.00
# 153.00
# 165.00
# 231.00
# Data loaded successfully!

# %%
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
# Out:
# EELS jul11_18.e02 not preprocessed, now preprocessing...
# 6 spikes found at the following locations:
# 99.00
# 129.00
# 150.00
# 153.00
# 165.00
# 231.00
# Data loaded successfully!

# %%
e.plot_data(cutoff=300)
