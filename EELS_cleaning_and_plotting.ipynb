# %%
# %matplotlib inline

from EELSLib import EELS

# %%
filename = 'apr25_18.e01'
e = EELS(filename)

ymax = 5
spike_removal = True

e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS apr25_18.e01 not preprocessed, now preprocessing...
# 1 spikes found at the following locations:
# 158.00
# Data loaded successfully!

# %%
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
# Out:
# EELS apr25_18.e01 not preprocessed, now preprocessing...
# 1 spikes found at the following locations:
# 158.00
# Data loaded successfully!

# %%
e.plot_data(cutoff=300)
