# %%
# %matplotlib inline
from lib.eels import EELS
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2019-01-23 02:23:41.911622] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2019-01-23 02:23:41.912682] TRACE: Program: Folder located successfully: /Users/yang/Dropbox (MIT)/Little Machine Data
# [2019-01-23 02:23:42.052453] TRACE: Program: Files transfer completed

# %%
filename = 'aug02_18.e02'
e = EELS(filename)

ymax = 100
spike_removal = True

e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS aug02_18.e02 already preprocessed, loading data...
# Data loaded successfully!

# %%
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
# Out:
# EELS aug02_18.e02 already preprocessed, loading data...
# Data loaded successfully!

# %%
e.plot_data(cutoff=300)
