# %%
import matplotlib.pyplot as plt
from LittleMachine_TDS_Lib import load_sensitivity, li_slope
import numpy as np

# Corresponding pressures
high_p = 2 * 10 ** (-9)
middle_p = 1 * 10 ** (-9)
low_p = 5 * 10 ** (-10)

# Change this for the data interested
filename = 'nov01_17.d03'

# Load data
counts, time = load_sensitivity(filename)
plt.ion()
plt.show()
plt.plot(time, counts)
plt.draw()
plt.pause(0.001)
