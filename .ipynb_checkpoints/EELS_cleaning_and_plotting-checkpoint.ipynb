# %%
from EELSLib import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import EELSLib
import importlib

# %matplotlib inline

# %%
importlib.reload(EELSLib)
from EELSLib import *

# %%
filename = 'feb22_18.e03'
e = EELS(filename)
ymax = 15
spike_removal = True
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=False)
# Out:
# EELS feb22_18.e03 not preprocessed, now preprocessing...
# 8 spikes found at the following locations:
# 135
# 153
# 154
# 159
# 177
# 179
# 181
# 223
# Data loaded successfully!

# %%
e.load_data(ymax=ymax, spike_removal=spike_removal, overwrite=True)
e.plot_data(cutoff=300)
# Out:
# EELS feb22_18.e03 not preprocessed, now preprocessing...
# 8 spikes found at the following locations:
# 135
# 153
# 154
# 159
# 177
# 179
# 181
# 223
# Data loaded successfully!
