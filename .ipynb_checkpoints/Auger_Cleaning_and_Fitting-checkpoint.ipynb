# %%
from LittleMachineLib import Auger
# %matplotlib inline

# %%
# path = '/Users/qingliu/Dropbox (MIT)/littlemachine'
filename = 'aug17_17.a02'

# %%
a = Auger(filename)
a.plot_data()
a.fit_Au_coverage()
# Out:
# Data has not been loaded yet, calling load_data()...
# Auger file aug17_17.a02 has been preprocessed, loading the data...
# Data loaded successfully!
# Au coverage is 0.513 ML
