# %%
from AugerLib import Auger

# %%
filename = "mar23_18.a02"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger mar23_18.a02 already preprocessed, loading data...
# Data loaded successfully!

# %%
a.fit_Au_coverage()
# Out:
# "{'A': array([ 0.231,  0.126,  0.322]), 'B': array([ 0.276,  0.258,  0.294]), 'C': array([ 0.259,  0.239,  0.279])}"
