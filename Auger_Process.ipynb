# %%
from lib.auger import Auger
from lib.file_transfer import file_transfer

# %%
file_transfer()
# Out:
# [2019-01-23 02:46:52.470273] NOTICE: Startup: Logging initialized, level: 9, mode: stdout mod
# [2019-01-23 02:46:52.471240] TRACE: Program: Folder located successfully: /Users/yang/Dropbox (MIT)/Little Machine Data
# [2019-01-23 02:46:52.613051] TRACE: Program: Files transfer completed

# %%
filename = "aug10_18.a02"

# %%
a = Auger(filename)

# %%
a.plot_data()
# Out:
# Auger aug10_18.a02 already preprocessed, loading data...
# Data loaded successfully!

# %%
a.fit_Au_coverage(energy_calibration=False, target_energy=54)
# Out:
# "{'A': array([0.445, 0.04 ]), 'B': array([0.437, 0.03 ])}"
